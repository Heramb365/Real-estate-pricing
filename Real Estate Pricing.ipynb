# %%
import pandas as pd

# %%
housing = pd.read_csv("data.csv")

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = "median")
imputer.fit(housing)
housing = pd.DataFrame(imputer.transform(housing), columns = housing.columns)
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  511.000000  511.000000  511.000000  511.000000  511.000000  511.000000
# mean     3.584139   11.252446   11.151096    0.068493    0.554757    6.285129
# std      8.564433   23.234838    6.828175    0.252838    0.115310    0.693941
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082325    0.000000    5.190000    0.000000    0.449000    5.897000
# 50%      0.261690    0.000000    9.690000    0.000000    0.538000    6.211000
# 75%      3.621175   12.500000   18.100000    0.000000    0.624000    6.605000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  511.000000  511.000000  511.000000  511.000000  511.000000  511.000000
# mean    68.616243    3.783876    9.485323  407.440313   18.500000  356.600900
# ...

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.211  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     511 non-null    float64
#  1   ZN       511 non-null    float64
#  2   INDUS    511 non-null    float64
#  3   CHAS     511 non-null    float64
#  4   NOX      511 non-null    float64
#  5   RM       511 non-null    float64
#  6   AGE      511 non-null    float64
#  7   DIS      511 non-null    float64
#  8   RAD      511 non-null    float64
#  9   TAX      511 non-null    float64
#  10  PTRATIO  511 non-null    float64
#  11  B        511 non-null    float64
#  12  LSTAT    511 non-null    float64
#  13  MEDV     511 non-null    float64
# dtypes: float64(14)
# memory usage: 56.0 KB

# %%
housing['CHAS'].value_counts()
# Out:
# 0.0    476
# 1.0     35
# Name: CHAS, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  511.000000  511.000000  511.000000  511.000000  511.000000  511.000000
# mean     3.584139   11.252446   11.151096    0.068493    0.554757    6.285129
# std      8.564433   23.234838    6.828175    0.252838    0.115310    0.693941
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082325    0.000000    5.190000    0.000000    0.449000    5.897000
# 50%      0.261690    0.000000    9.690000    0.000000    0.538000    6.211000
# 75%      3.621175   12.500000   18.100000    0.000000    0.624000    6.605000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  511.000000  511.000000  511.000000  511.000000  511.000000  511.000000
# mean    68.616243    3.783876    9.485323  407.440313   18.500000  356.600900
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHAS'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index,test_index in split.split(housing, housing['CHAS']):
    train = housing.loc[train_index]
    test = housing.loc[test_index]

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# 0    380
# 1     28
# Name: CHAS, dtype: int64

# %% [markdown]
# ## Looking for Correlations

# %%
corr_matrix = housing.corr()

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.661112
# ZN         0.339767
# B          0.317941
# DIS        0.233469
# CHAS       0.164782
# AGE       -0.368203
# RAD       -0.379016
# CRIM      -0.380072
# NOX       -0.411486
# PTRATIO   -0.447464
# TAX       -0.459274
# INDUS     -0.463269
# LSTAT     -0.562960
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["MEDV","RM", "ZN", "LSTAT"]
scatter_matrix(housing[attributes], figsize =(12,8))
# Out:
# array([[<AxesSubplot:xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='ZN', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind="scatter", x="RM",y="MEDV",alpha=0.8)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN      INDUS        CHAS         NOX          RM  \
# count  408.000000  408.000000  408.00000  408.000000  408.000000  408.000000
# mean     3.574915   10.730392   11.37527    0.068627    0.558200    6.264642
# std      8.066171   22.067428    6.83855    0.253130    0.116078    0.691789
# min      0.006320    0.000000    0.74000    0.000000    0.389000    3.561000
# 25%      0.087962    0.000000    5.32000    0.000000    0.453000    5.888750
# 50%      0.286735    0.000000    9.90000    0.000000    0.538000    6.209000
# 75%      3.716457   12.500000   18.10000    0.000000    0.625750    6.593500
# max     73.534100  100.000000   27.74000    1.000000    0.871000    8.704000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  408.000000  408.000000  408.000000  408.000000  408.000000  408.000000
# mean    69.169363    3.738277    9.666667  411.227941   18.500245  353.601397
# ...

# %%
train.shape
# Out:
# (408, 14)

# %%
test.shape
# Out:
# (103, 14)

# %%
train.describe()
# Out:
#              CRIM          ZN      INDUS        CHAS         NOX          RM  \
# count  408.000000  408.000000  408.00000  408.000000  408.000000  408.000000
# mean     3.574915   10.730392   11.37527    0.068627    0.558200    6.264735
# std      8.066171   22.067428    6.83855    0.253130    0.116078    0.691782
# min      0.006320    0.000000    0.74000    0.000000    0.389000    3.561000
# 25%      0.087962    0.000000    5.32000    0.000000    0.453000    5.888750
# 50%      0.286735    0.000000    9.90000    0.000000    0.538000    6.211000
# 75%      3.716457   12.500000   18.10000    0.000000    0.625750    6.593500
# max     73.534100  100.000000   27.74000    1.000000    0.871000    8.704000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  408.000000  408.000000  408.000000  408.000000  408.000000  408.000000
# mean    69.169363    3.738277    9.666667  411.227941   18.500245  353.601397
# ...

# %%
test.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     3.620674   13.320388   10.263107    0.067961    0.541116    6.365913
# std     10.350426   27.400162    6.746703    0.252910    0.111724    0.699972
# min      0.009060    0.000000    0.460000    0.000000    0.385000    4.138000
# 25%      0.061400    0.000000    4.905000    0.000000    0.447500    5.962000
# 50%      0.217190    0.000000    8.140000    0.000000    0.515000    6.211000
# 75%      1.974730    0.000000   18.100000    0.000000    0.611500    6.672500
# max     88.976200   90.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean    66.425243    3.964499    8.766990  392.436893   18.499029  368.482427
# ...

# %%
X_train=train.iloc[:,0:13].values
Y_train=train.iloc[:,13].values
X_test=test.iloc[:,0:13].values
Y_test=test.iloc[:,13].values

# %%
housing_num_tr.shape
# Out:
# (511, 14)

# %% [markdown]
# ## Selecting a desired model

# %%
def get_models(X_train,Y_train):
        #Linear regression
        from sklearn.linear_model import LinearRegression
        lin=LinearRegression()
        lin.fit(X_train,Y_train)
        
        #Decision Tree
        from sklearn.tree import DecisionTreeRegressor
        tree=DecisionTreeRegressor()
        tree.fit(X_train,Y_train)
        
        #Random Forest
        from sklearn.ensemble import RandomForestRegressor
        forest=RandomForestRegressor()
        forest.fit(X_train,Y_train)
        
        print('[0]linear regression accuracy:',lin.score(X_train,Y_train))
        print('[1]Decision tree accuracy:',tree.score(X_train,Y_train))
        print('[2]Random forest accuracy:',forest.score(X_train,Y_train))
        
        return lin,tree,forest

# %%
model_list = get_models(X_train, Y_train)
# Out:
# [0]linear regression accuracy: 0.7051672246120495
# [1]Decision tree accuracy: 1.0
# [2]Random forest accuracy: 0.9761722491501842

# %% [markdown]
# ## Evaluating the Models

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
def get_score (X, Y, model):
    scores = cross_val_score(model, X, Y,scoring="neg_mean_squared_error",cv=10)
    rmse_scores = np.sqrt(-scores)
    return np.mean(rmse_scores)

# %%
for model in model_list:
    print(get_score(X_train, Y_train, model))
# Out:
# 5.206550476464633
# 4.360726002856148
# 3.821048964911289

# %%
for model in model_list:
    print(get_score(X_test, Y_test, model))
# Out:
# 7.377188219728946
# 6.921407164479784
# 5.330704591335882

# %% [markdown]
# ## Creating a pipeline

# %%
from joblib import dump, load
dump(model_list[2], 'Dragon.joblib')
# Out:
# ['Dragon.joblib']

# %%
loaded_model = load('Dragon.joblib')

# %%
get_score(X_test, Y_test, loaded_model)
# Out:
# 5.398383173575556
